jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (253)_Resize.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (210)_Resize.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (264)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (92)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (78)_PerspectiveTransform.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (352)_ElasticTransformation.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (263)_Dropout.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (502)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (95)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (591)_PerspectiveTransform.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (580).jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (312)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (53)_GaussianBlur.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (473)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (283)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (363)_PerspectiveTransform.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (607)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (479)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (459)_ElasticTransformation.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (419)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (16)_PiecewiseAffine.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (55)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (415)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (223)_GaussianBlur.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (527)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (553)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (90)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (33)_ElasticTransformation.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (335)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (249)_GaussianBlur.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (592)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (566)_Fliplr.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (585)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (12).jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (314)_Fliplr.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (525)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (159)_LinearContrast.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (324)_ElasticTransformation.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (510)_ElasticTransformation.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (110)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (50)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (588)_Dropout.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (559)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (282)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (25)_PerspectiveTransform.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (372)_Fliplr.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (549)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (575)_Dropout.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (165)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (553)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (581)_PiecewiseAffine.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (437)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (229)_Rotate.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (168)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (100)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (594)_AdditiveGaussianNoise.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (424)_Crop.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (359)_PiecewiseAffine.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (577)_Multiply.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (618)_Resize.jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (395).jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (317).jpg
# /kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Augmented Dataset/Non-Cancer/IMG (173)_LinearContrast.jpg

# %%
import os
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torchvision import transforms
from sklearn.model_selection import train_test_split
from datasets import load_metric
from sklearn.metrics import accuracy_score
from datasets import load_dataset
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import random
# !pip install -U accelerate
# Out:
# Requirement already satisfied: accelerate in /opt/conda/lib/python3.10/site-packages (0.32.1)
# Collecting accelerate
#   Downloading accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.17 in /opt/conda/lib/python3.10/site-packages (from accelerate) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (21.3)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from accelerate) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from accelerate) (6.0.1)
# Requirement already satisfied: torch>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (2.1.2)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.23.4)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from accelerate) (0.4.3)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2024.5.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.66.4)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.0->accelerate) (3.1.1)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (1.13.0)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.10.0->accelerate) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.10.0->accelerate) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2024.7.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.10.0->accelerate) (1.3.0)
# Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 2.7 MB/s eta 0:00:00a 0:00:01m
# Installing collected packages: accelerate
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.32.1
#     Uninstalling accelerate-0.32.1:
#       Successfully uninstalled accelerate-0.32.1
# Successfully installed accelerate-0.33.0

# %% [markdown]
# **Set random seed for reproducibility**

# %%
import random
random.seed(10)

# %% [markdown]
# **Load dataset**

# %%
dataset = load_dataset(
    "imagefolder",
    data_dir="/kaggle/input/mamography/Mammogram Mastery A Robust Dataset for Breast Cancer Detection and Medical Education/Breast Cancer Dataset/Original Dataset",
    split='train'
)
# Out:
# Resolving data files:   0%|          | 0/745 [00:00<?, ?it/s]
# Downloading data:   0%|          | 0/745 [00:00<?, ?files/s]
# Generating train split: 0 examples [00:00, ? examples/s]

# %% [markdown]
# **Split dataset**

# %%
from collections import Counter
splits = dataset.train_test_split(test_size=0.2, seed=30, shuffle=True)
train_ds = splits['train']
val_ds = splits['test']

print(train_ds)
print(val_ds)

# Obtain the labels of each dataset
train_labels = [x['label'] for x in train_ds]
val_labels = [x['label'] for x in val_ds]

# Calculate the frequency of each label
train_counter = Counter(train_labels)
val_counter = Counter(val_labels)
# Out:
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 596
# })
# Dataset({
#     features: ['image', 'label'],
#     num_rows: 149
# })

# %%
plt.figure(figsize=(10, 5))
plt.bar(train_counter.keys(), train_counter.values())
plt.title('Class distribution - Training Dataset')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')
plt.xticks(list(train_counter.keys()))
plt.show()

# %%
plt.figure(figsize=(10, 5))
plt.bar(val_counter.keys(), val_counter.values(), color='g')
plt.title('Class distribution - Validation Dataset')
plt.xlabel('Class Labels')
plt.ylabel('Frequency')
plt.xticks(list(val_counter.keys()))
plt.show()

# %% [markdown]
# **Prepare label mapping**

# %%
labels = dataset.features["label"].names
label2id, id2label = dict(), dict()
for i, label in enumerate(labels):
    label2id[label] = i
    id2label[i] = label
print(label2id)
print(id2label)
# Out:
# {'Cancer': 0, 'Non-Cancer': 1}
# {0: 'Cancer', 1: 'Non-Cancer'}

# %%
val_ds[0]['image']
# Out:
# <PIL.Image.Image image mode=RGB size=1920x1080>

# %%
from torchvision.transforms import (
    CenterCrop,
    Compose,
    Normalize,
    RandomHorizontalFlip,
    RandomResizedCrop,
    Resize,
    ToTensor
)
class DummyProcessor:
    def __init__(self):
        self.image_mean = [0.485, 0.456, 0.406]
        self.image_std = [0.229, 0.224, 0.225]
        self.size = {"height": 224, "width": 224}

processor = DummyProcessor()
image_mean, image_std = processor.image_mean, processor.image_std
size = processor.size["height"]

normalize = Normalize(mean=image_mean, std=image_std)
_train_transforms = Compose([
    RandomResizedCrop(size),
    RandomHorizontalFlip(),
    ToTensor(),
    normalize,
])

_val_transforms = Compose([
    Resize(size),
    CenterCrop(size),
    ToTensor(),
    normalize,
])

def train_transforms(examples):
    examples['pixel_values'] = [_train_transforms(image.convert("RGB")) for image in examples['image']]
    return examples

def val_transforms(examples):
    examples['pixel_values'] = [_val_transforms(image.convert("RGB")) for image in examples['image']]
    return examples

train_ds.set_transform(train_transforms)
val_ds.set_transform(val_transforms)

from transformers import ViTForImageClassification

model = ViTForImageClassification.from_pretrained(
    'google/vit-base-patch16-224-in21k',
    id2label=id2label,
    label2id=label2id
)

def collate_fn(batch):
    pixel_values = torch.stack([x["pixel_values"] for x in batch])
    labels = torch.tensor([x["label"] for x in batch])
    return {"pixel_values": pixel_values, "labels": labels}

def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    return dict(accuracy=accuracy_score(predictions, labels))
# Out:
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments, Trainer

metric_name = "accuracy"

args = TrainingArguments(
    "breast_cancer_detection_v12",
    save_strategy="no",
    evaluation_strategy="epoch",
    learning_rate=2e-5,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=4,
    num_train_epochs=10,
    weight_decay=0.01,
    load_best_model_at_end=False,
    metric_for_best_model=metric_name,
    logging_dir='logs',
    report_to='tensorboard',
    remove_unused_columns=False,
    logging_steps=10,  # Log metrics every 10 steps
)

trainer = Trainer(
    model,
    args,
    train_dataset=train_ds,
    eval_dataset=val_ds,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    tokenizer=processor,
)
train_results = trainer.train()
eval_results = trainer.evaluate(val_ds)
print(f"Validation Loss: {eval_results['eval_loss']:.4f}")
print(f"Validation Accuracy: {eval_results['eval_accuracy']:.4f}")
test_results = trainer.predict(val_ds)
y_true = test_results.label_ids
y_pred = np.argmax(test_results.predictions, axis=1)
test_accuracy = accuracy_score(y_true, y_pred)
print(f"Testing Accuracy: {test_accuracy:.4f}")
labels = train_ds.features['label'].names
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot(xticks_rotation=45)
plt.show()
# Out:
# 2024-08-21 13:06:18.761831: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-21 13:06:18.761933: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-21 13:06:18.888458: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# /opt/conda/lib/python3.10/site-packages/transformers/training_args.py:1494: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='190' max='190' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [190/190 04:46, Epoch 10/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.520800</td>
#       <td>0.352173</td>
#       <td>0.838926</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.428300</td>
#       <td>0.276188</td>
#       <td>0.838926</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.303000</td>
#       <td>0.199861</td>
#       <td>0.885906</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.288600</td>
#       <td>0.156021</td>
#       <td>0.979866</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.266600</td>
#       <td>0.121834</td>
#       <td>0.979866</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.194500</td>
#       <td>0.109558</td>
#       <td>0.986577</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.252000</td>
#       <td>0.112579</td>
#       <td>0.979866</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.210600</td>
#       <td>0.088952</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.205100</td>
#       <td>0.085984</td>
#       <td>1.000000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.228000</td>
#       <td>0.086377</td>
#       <td>0.993289</td>
#     </tr>
#   </tbody>
# </table><p>
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Validation Loss: 0.0864
# Validation Accuracy: 0.9933
# /opt/conda/lib/python3.10/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Testing Accuracy: 0.9933

# %% [markdown]
# **preiction**

# %%
import random
from PIL import Image
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)
num_samples = 5
samples = random.sample(list(val_ds), num_samples)
for sample in samples:
    image = sample['image']
    real_label = id2label[sample['label']]
    input_tensor = _val_transforms(image.convert("RGB")).unsqueeze(0)  # Add batch dimension
    input_tensor = input_tensor.to(device)  # Move input tensor to the same device as the model
    model.eval()
    with torch.no_grad():
        outputs = model(input_tensor)
    predicted_label_id = outputs.logits.argmax(-1).item()
    predicted_label = id2label[predicted_label_id]
    plt.figure(figsize=(4, 4))
    plt.imshow(image)
    plt.title(f"Real: {real_label}\nPredicted: {predicted_label}")
    plt.axis("off")
    plt.show()
